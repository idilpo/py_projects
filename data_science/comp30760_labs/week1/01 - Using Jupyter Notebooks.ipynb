# %% [markdown]
# # Using Jupyter Notebooks

# %% [markdown]
# **Jupyter Notebooks** provide an interactive web-based environment for writing and running Python code. We will use Jupyter notebooks for many of the labs and assignments in this module.

# %% [markdown]
# Jupyter Notebooks have two fundamental types of cells:
# 1. *Markdown cells*: These contain text content for explaining the contents our notebook.
# 2. *Code cells*: These allow us to enter and execute Python code.

# %% [markdown]
# ## Code Cells

# %% [markdown]
# To get started, review the lectures notes on how to start the Jupyter Notebook Server and create a new notebook in your web browser.

# %% [markdown]
# You can then run Python code in a code cell by hitting Shift-Enter or by pressing the ‘Play‘ button in the toolbar. You can modify and re-run code cells multiple times in any order.

# %% [markdown]
# When a code cell is executed, the code that it contains is sent to the ‘kernel‘ associated with the notebook (i.e. the Python engine running in the background). The results that are returned from this computation are then displayed in the notebook as the cell’s output. Note that some code will not have an output.

# %%
1 + 2   # output is the result

# %%
x = 25  # no output for this code

# %%
print(x)  # output is generated by the print function

# %% [markdown]
# ## Markdown Cells

# %% [markdown]
# It can often be helpful to provide explanatory text in notebooks. [Markdown](http://daringfireball.net/projects/markdown/) is a lightweight type of markup language with plain text formatting syntax which can be rendered as HTML. While there is no formal definition of the Markdown language, Jupyter supports a set of commands which are commonly used elsewhere (e.g. Github, Reddit).

# %% [markdown]
# To enter a  Markdown cell, choose the cell dropdown list in the toolbar and set the type to ‘Markdown’.

# %% [markdown]
# **Paragraphs**: Paragraphs in Markdown are just one or more lines of consecutive text followed by one or more blank lines.

# %% [markdown]
# This is a paragraph of text.

# %% [markdown]
# **Styling Text**: We can create a heading by adding one or more `#` symbols before the heading text. The number of `#`'s used will determine the size of the font.

# %% [markdown]
# # Heading 1
# ## Heading 2
# ### Heading 3
# #### Heading 4

# %% [markdown]
# You can format text as *italic* or **bold** using one or two `*`'s respectively.

# %% [markdown]
# This is normal text
# *This text will be in italics*
# **And this text will be in bold**

# %% [markdown]
# **Unordered lists**: We can make an unordered (bulleted) list by prefixing lines with either the `*` or `-` character.

# %% [markdown]
# * My item
# * Another item
# * Yet another item

# %% [markdown]
# - My item
# - Another item
# - Yet another item

# %% [markdown]
# **Ordered lists**: We can make an ordered (numbered) list by prefixing lines with a number.

# %% [markdown]
# 1. My first item
# 2. Next item
# 3. Final item

# %% [markdown]
# We can create a hyperlink by wrapping text in square brackets (`[ ]`) and then wrapping the link in parentheses (`( )`).

# %% [markdown]
# Go to [the UCD homepage](http://www.ucd.ie)

# %% [markdown]
# ## More Resources

# %% [markdown]
# Jupyter Resources
# * [Jupyter Official Documentation](https://docs.jupyter.org/en/latest/)
#
# Markdown Resources
# * [Mastering Markdown](https://guides.github.com/features/mastering-markdown/) from Github
# * [Original Markdown Syntax Specification](https://daringfireball.net/projects/markdown/syntax) from John Gruber
# * [Markdown Cheat Sheet](http://nestacms.com/docs/creating-content/markdown-cheat-sheet) from Nesta CMS
