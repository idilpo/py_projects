# %%
import pandas as pd
import matplotlib as plt

# %%
def fetch(url):
    data = pd.read_csv(url)
    data.set_index("Level", inplace=True)
    return data

# %%
df = fetch("/Users/idilbilgic/Desktop/py_projects/HayDay/HayDay_data.csv")
df
# Out:
#               Product     Type      Produced by  \
# Level
# 1               Wheat     Crop            Field
# 1                 Egg  Produce        Livestock
# 2                Corn     Crop            Field
# 2               Bread  Produce           Bakery
# 3        Chicken Feed     Feed        Feed Mill
# ...               ...      ...              ...
# 47      Hot Chocolate  Produce     Coffee Kiosk
# 47        Tomato Soup  Produce     Soup Kitchen
# 48          Red Scarf  Produce             Loom
# 48     Lobster Skewer  Produce        BBQ Grill
# 48            Beeswax  Produce  Honey Extractor
#
#                                                    Needs  \
# Level
# 1                                                    NaN
# 1                                       Chicken Feed (1)
# 2                                                    NaN
# 2                                              Wheat (2)
# 3                                    Wheat (2), Corn (1)
# ...

# %%
def stats(df, column):
    rows = []
    for product in df:
        print(product)
        row = {"Level": df[product]}
        row["Product"] = product
        row["Min"] = df[product][column].min()
        row["Max"] = df[product][column].max()
        row["Mean"] = df[product][column].mean()
        row["Median"] = df[product][column].median()
        rows.append(row)
    return pd.DataFrame(rows).set_index("Level")

# %%
plt.figure(figsize=(20,12))
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.title(label="Network 1 Node Graph", fontsize=20, color="mediumseagreen")
plt.show()

# %%
for row in data:

# %%
def level_identifier(level, dataframe):
    for
